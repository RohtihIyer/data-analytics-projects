# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from numpy import median
from numpy import mean

# %%
a=[1,2,3,4,5]
b=[100,50,200,150,300]
plt.plot(a,b)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
a=[1,2,3,4,5]
b=[100,50,200,150,300]
sns.lineplot(x=a,y=b)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
a=[1,2,3,4,5]
b=[100,50,200,150,300]
df=pd.DataFrame({"x:":a,"y":b})

# %%
df
# Out:
#    x:    y
# 0   1  100
# 1   2   50
# 2   3  200
# 3   4  150
# 4   5  300

# %%
var=[10,30,50,70,90]
var1=[234,678,456,700,805]
df=pd.DataFrame({"var":var,"var1":var1})
sns.lineplot(x="var",y="var1",data=df)
plt.show()

# %%
df1=sns.load_dataset("penguins")

# %%
df1
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.lineplot(x="bill_length_mm",y="flipper_length_mm",data=df1)
plt.show()

# %%
sns.lineplot(x="bill_length_mm",y="flipper_length_mm",data=df1,hue="sex")
plt.show()

# %%
sns.set(style="dark")
fb = sns.load_dataset("fmri")
sns.lineplot(x="timepoint",
             y="signal",
             hue="region",
             style="event",
             data=fb)
plt.show()

# %%
sns.lineplot(x="bill_length_mm",y="flipper_length_mm",data=df1,hue="sex",palette="rocket_r")
plt.show()

# %%
sns.lineplot(x="bill_length_mm",y="flipper_length_mm",data=df1,hue="sex",style="sex",palette="rocket_r",markers=["o","^"])
plt.show()

# %%
df1=sns.load_dataset("penguins").head(50)

# %%
df1
# Out:
#    species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0   Adelie  Torgersen            39.1           18.7              181.0
# 1   Adelie  Torgersen            39.5           17.4              186.0
# 2   Adelie  Torgersen            40.3           18.0              195.0
# 3   Adelie  Torgersen             NaN            NaN                NaN
# 4   Adelie  Torgersen            36.7           19.3              193.0
# 5   Adelie  Torgersen            39.3           20.6              190.0
# 6   Adelie  Torgersen            38.9           17.8              181.0
# 7   Adelie  Torgersen            39.2           19.6              195.0
# 8   Adelie  Torgersen            34.1           18.1              193.0
# 9   Adelie  Torgersen            42.0           20.2              190.0
# 10  Adelie  Torgersen            37.8           17.1              186.0
# 11  Adelie  Torgersen            37.8           17.3              180.0
# ...

# %%
sns.lineplot(x="bill_length_mm",y="flipper_length_mm",data=df1,hue="sex",style="sex",palette="rocket_r",markers=["o","^"])
plt.show()

# %%
sns.lineplot(x="bill_length_mm",y="flipper_length_mm",data=df1,hue="sex",style="sex",palette="rocket_r",markers=["o","^"])
plt.show()
plt.grid
# Out:
# <function matplotlib.pyplot.grid(visible: 'bool | None' = None, which: "Literal['major', 'minor', 'both']" = 'major', axis: "Literal['both', 'x', 'y']" = 'both', **kwargs) -> 'None'>

# %%
data = sns.load_dataset("iris")
sns.lineplot(x="sepal_length", y="sepal_width", data=data)
plt.show()

# %%
sns.lineplot(x="bill_length_mm",y="flipper_length_mm",data=df1,hue="sex",style="sex",palette="rocket_r",markers=["o","^"])
plt.grid
plt.title("This a Graph of Penguins")
plt.show()

# %%
data=sns.load_dataset("tips")
sns.lineplot(x="total_bill",y="size",hue="sex",style="sex",data=data)
plt.show()

# %%
sns.set(style="darkgrid")
ru=np.random.RandomState(10)
d=ru.normal(size=100)
sns.histplot(d,kde=True,color="m")
plot=sns.histplot(d,kde=True,color="m")
print(plot)
plt.show()
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %%
sns.set(rc={"figure.figsize":(3,2)});np.random.seed(0)
x=np.random.randn(10)
ans=sns.distplot(x)
plt.show()
# Out:
# C:\Users\RAHUL\AppData\Local\Temp\ipykernel_10916\1026892271.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ans=sns.distplot(x)

# %%
sns.set(rc={"figure.figsize":(3,2)});np.random.seed(0)
x=np.random.randn(10)
ans=sns.displot(x)
plt.show()

# %%
from pylab import*
sns.set(rc={"figure.figsize":(5,4)});np.random.seed(0)
x=np.random.randn(10)
subplot=(2,2,1)
ax=sns.histplot(x)
subplot=(2,2,2)
ax=sns.histplot(x)
subplot=(2,2,3)
ax=sns.histplot(x)
subplot=(2,2,4)
ax=sns.kdeplot(x,shade=True,color="m")
plt.show()
# Out:
# C:\Users\RAHUL\AppData\Local\Temp\ipykernel_10916\1376393254.py:11: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   ax=sns.kdeplot(x,shade=True,color="m")

# %%
titanic=sns.load_dataset("titanic")
age1=titanic["age"].dropna()
sns.histplot(age1,bins=30,kde=False)
plt.show()

# %%
titanic=sns.load_dataset('titanic')
age1=titanic['age'].dropna()

fig,axes=plt.subplots(1,2)
sns.distplot(age1,ax=axes[0])
plt.grid(True)
sns.distplot(age1,rug=True,ax=axes[1])
plt.show()
# Out:
# C:\Users\RAHUL\AppData\Local\Temp\ipykernel_10916\1374967335.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(age1,ax=axes[0])
# C:\Users\RAHUL\AppData\Local\Temp\ipykernel_10916\1374967335.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
sns.set(style="ticks")
ds=sns.load_dataset("anscombe")
sns.lmplot(x="x",y="y",data=ds)
plot=sns.lmplot(x="x",y="y",data=ds)
print(plot)
plt.show()

# %%
titanic=sns.load_dataset("titanic")
titanic.head()
sns.lmplot(x="fare",y="age",hue="class",data=titanic)
plt.show()

# %%
titanic=sns.load_dataset("titanic")
titanic.head()
sns.lmplot(x="fare",y="age",hue="class",data=titanic,markers=["o","d","*"])
plt.show()

# %%
titanic=sns.load_dataset("titanic")
titanic.head()
sns.lmplot(x="fare",y="age",hue="class",col="class",data=titanic)
plt.show()

# %%
tips=sns.load_dataset("tips")
tips.head()
sns.histplot(data=tips,x="total_bill",hue="sex",bins=20)
plt.show()

# %%
tips=sns.load_dataset("tips")
tips.head()
sns.histplot(data=tips,x="total_bill",hue="sex",element="poly")
plt.show()

# %%
tips=sns.load_dataset("tips")
tips.head()
sns.histplot(data=tips,x="total_bill",hue="sex",shrink=.7)
plt.show()

# %%
tips=sns.load_dataset("tips")
tips.head()
sns.histplot(data=tips,x="total_bill",log_scale=True,element="step",fill=False)
plt.show()

# %%
df=sns.load_dataset("titanic")
sns.barplot(x="class",y="fare",data=df)
plt.show()

# %%
df=sns.load_dataset("titanic")
sns.barplot(x="class",y="fare",hue="sex",data=df)
plt.show()

# %%
df=sns.load_dataset("titanic")
sns.barplot(x="fare",y="class",hue="sex",data=df)
plt.show()

# %%
df=sns.load_dataset("titanic")
sns.barplot(x="fare",y="class",hue="sex",data=df,order=["Third","Second","First"])
plt.show()

# %%
df=sns.load_dataset("titanic")
sns.barplot(x="class",y="fare",hue="sex",data=df,color="salmon")
plt.show()
# Out:
# C:\Users\RAHUL\AppData\Local\Temp\ipykernel_16984\1966713955.py:2: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:salmon'` for the same effect.
#
#   sns.barplot(x="class",y="fare",hue="sex",data=df,color="salmon")

# %%
df=sns.load_dataset("titanic")
sns.barplot(x="class",y="fare",hue="sex",data=df,ci=None)
plt.show()
# Out:
# C:\Users\RAHUL\AppData\Local\Temp\ipykernel_16984\2617504122.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x="class",y="fare",hue="sex",data=df,ci=None)

# %%
df=sns.load_dataset("titanic")
sns.barplot(x="class",y="fare",hue="sex",data=df,errorbar=None)
plt.show()

# %%
df = sns.load_dataset('titanic')
sns.barplot(x = 'class', y = 'fare',
            hue = 'sex', data = df, palette='pastel')
plt.show()

# %%
df = sns.load_dataset('titanic')
sns.barplot(x = 'class', y = 'fare', hue = 'sex', data = df, estimator=median)
plt.show()

# %%
df = sns.load_dataset('titanic')
sns.barplot(x = 'class', y = 'fare', hue = 'sex', data = df, estimator=mean)
plt.show()

# %%
df = sns.load_dataset('titanic')
sns.barplot(x = 'class', y = 'fare', hue = 'sex', data = df, saturation = 0.5)
plt.show()

# %%
df = sns.load_dataset('titanic')

sns.barplot(x="class", y="fare", data=df,
            linewidth=2.5, facecolor=(1, 1, 1, 0),
            errcolor=".2", edgecolor=".2")
# Out:
# C:\Users\RAHUL\AppData\Local\Temp\ipykernel_16984\2587959546.py:3: FutureWarning:
#
# The `errcolor` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'color': '.2'}` instead.
#
#   sns.barplot(x="class", y="fare", data=df,
# <Axes: xlabel='class', ylabel='fare'>

# %%
sns.set(style="whitegrid")
fb=sns.load_dataset("fmri")
sns.scatterplot(x="timepoint",y="signal",data=fb)
plt.plot()
# Out:
# []

# %%
sns.set(style="whitegrid")
fb=sns.load_dataset("fmri")
sns.scatterplot(x="timepoint",y="signal",hue="region",style="event",data=fb)
plt.plot()
# Out:
# []

# %%
sns.set(style="whitegrid")
tip=sns.load_dataset("tips")
sns.scatterplot(x="day",y="tip",data=tip)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.set(style="whitegrid")
tip=sns.load_dataset("tips")
sns.scatterplot(x="day",y="tip",data=tip,marker="d")
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.set(style="whitegrid")
tip=sns.load_dataset("tips")
sns.scatterplot(x="day",y="tip",data=tip,hue="time")
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.set(style="whitegrid")
tip=sns.load_dataset("tips")
sns.scatterplot(x="day",y="tip",data=tip,hue="day")
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.set(style="whitegrid")
tip=sns.load_dataset("tips")
sns.scatterplot(x="day",y="tip",data=tip,hue="time",style="time")
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.set(style="whitegrid")
tip=sns.load_dataset("tips")
sns.scatterplot(x="day",y="tip",data=tip,hue="time",palette="pastel")
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.set(style="whitegrid")
tip=sns.load_dataset("tips")
sns.scatterplot(x="day",y="tip",data=tip,hue="size",size="size")
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
tip=sns.load_dataset("tips")
sns.scatterplot(x="day",y="tip",data=tip,hue="day",sizes=(30,200),legend="brief")
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.set(style="whitegrid")
tip=sns.load_dataset("tips")
sns.scatterplot(x="day",y="tip",data=tip,alpha=0.1)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
dts=sns.load_dataset("titanic")
dts.head()
sns.relplot(data=dts,x="age",y="fare")
plt.show()

# %%
dts=sns.load_dataset("titanic")
dts.head()
sns.relplot(data=dts,x="age",y="fare",hue="class")
plt.show()

# %%
dts=sns.load_dataset("titanic")
dts.head()
sns.relplot(data=dts,x="age",y="fare",hue="class",col="who",row="alive")
plt.show()

# %%
dts=sns.load_dataset("titanic")
dts.head()
sns.relplot(data=dts,x="age",y="fare",hue="class",kind="line")
plt.show()

# %%
dnf=sns.load_dataset("tips")
sns.countplot(x="sex",data=df)
plt.show()

# %%
df=sns.load_dataset("tips")
sns.countplot(x="sex",hue="smoker",data=df)
plt.show()

# %%
df=sns.load_dataset("tips")
sns.countplot(x="sex",data=df,palette="Set2")
plt.show()
# Out:
# C:\Users\RAHUL\AppData\Local\Temp\ipykernel_16984\1051542360.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="sex",data=df,palette="Set2")

# %%
df=sns.load_dataset("tips")
sns.countplot(x="sex",hue="sex",data=df,color="salmon")
plt.show()
# Out:
# C:\Users\RAHUL\AppData\Local\Temp\ipykernel_16984\2829939915.py:2: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:salmon'` for the same effect.
#
#   sns.countplot(x="sex",hue="sex",data=df,color="salmon")

# %%
df=sns.load_dataset("tips")
sns.countplot(x="sex",data=df,palette="Set2")
plt.show()
# Out:
# C:\Users\RAHUL\AppData\Local\Temp\ipykernel_11160\1051542360.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="sex",data=df,palette="Set2")

# %%
fb=sns.load_dataset("fmri")
sns.violinplot(x="timepoint",y="signal",data=fb)
# Out:
# <Axes: xlabel='timepoint', ylabel='signal'>

# %%
fb=sns.load_dataset("fmri")
sns.violinplot(x="timepoint",y="signal",hue="region",data=fb)
# Out:
# <Axes: xlabel='timepoint', ylabel='signal'>

# %%
sns.set(style="whitegrid")
tip=sns.load_dataset("tips")
sns.violinplot(x="day",y="tip",data=tip)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.set(style="whitegrid")
tip=sns.load_dataset("tips")
sns.stripplot(x="day",y="total_bill",data=tip)
plt.show()

# %%
sns.set(style="whitegrid")
tip=sns.load_dataset("tips")
sns.stripplot(x="day",y="total_bill",hue="day",data=tip)
plt.show()

# %%
sns.set(style="whitegrid")
fb=sns.load_dataset("fmri")
sns.swarmplot(x="timepoint",y="signal",data=fb)
# Out:
# C:\Users\RAHUL\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 69.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\RAHUL\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 67.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\RAHUL\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 66.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\RAHUL\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 46.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
sns.load_dataset("exercise")
# Out:
#     Unnamed: 0  id     diet  pulse    time     kind
# 0            0   1  low fat     85   1 min     rest
# 1            1   1  low fat     85  15 min     rest
# 2            2   1  low fat     88  30 min     rest
# 3            3   2  low fat     90   1 min     rest
# 4            4   2  low fat     92  15 min     rest
# ..         ...  ..      ...    ...     ...      ...
# 85          85  29   no fat    135  15 min  running
# 86          86  29   no fat    130  30 min  running
# 87          87  30   no fat     99   1 min  running
# 88          88  30   no fat    111  15 min  running
# 89          89  30   no fat    150  30 min  running
#
# [90 rows x 6 columns]

# %%
exercise=sns.load_dataset("exercise")
g=sns.catplot(x="time",y="pulse",hue="kind",data=exercise)

# %%
exercise=sns.load_dataset("exercise")
g=sns.catplot(x="time",kind="count",hue="kind",data=exercise)

# %%
exercise=sns.load_dataset("exercise")
g=sns.catplot(x="time",y="pulse",kind="bar",hue="kind",data=exercise)

# %%
exercise=sns.load_dataset("exercise")
g=sns.catplot(x="time",y="pulse",hue="kind",data=exercise,kind="violin")

# %%
exercise=sns.load_dataset("exercise")
g=sns.catplot(x="time",y="pulse",hue="kind",col="diet",data=exercise)

# %%
tips=sns.load_dataset("tips")
sns.catplot(x="day",y="total_bill",data=tips,kind="box");

# %%
x=np.random.randn(200)
y=np.random.randn(400)
sns.kdeplot(x)
# Out:
# <Axes: ylabel='Density'>

# %%
x=np.random.randn(200)
y=np.random.randn(400)
sns.kdeplot(x,shade=True)
# Out:
# C:\Users\RAHUL\AppData\Local\Temp\ipykernel_11160\840221222.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x,shade=True)
# <Axes: ylabel='Density'>

# %%
x=np.random.randn(200)
y=np.random.randn(400)
sns.kdeplot(x,shade=True,color="Green")
# Out:
# C:\Users\RAHUL\AppData\Local\Temp\ipykernel_11160\303341066.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x,shade=True,color="Green")
# <Axes: ylabel='Density'>

# %%
tips=sns.load_dataset("tips")
tips.head()
sns.kdeplot(data=tips,x="tip")
sns.rugplot(data=tips,x="tip")
plt.show()

# %%
data=sns.load_dataset("tips")
data.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips=sns.load_dataset("tips")
tips.head()
sns.jointplot(x="total_bill",y="tip",data=tips)
plt.show()

# %%
mydata=sns.load_dataset("penguins")
sns.pairplot(mydata,hue="sex")
plt.show()
